# %% [markdown]
# # #24 · Naive vs 2x2 DiD — comparison and recommendation
#
# @anushatiwari · due Friday 2026-09-25 · [issue #24](https://github.com/Break-Through-Tech/Estee-Lauder-1B-measuring-customer-delight/issues/24)
#
# **The deck asks for**
# - Compare naive to 2x2 DiD, discuss pros & cons
# - Which would you use for a business decision?
#
# **Already settled in [`../eda_final.ipynb`](../eda_final.ipynb) — don't redo**
# - §2–3 made the *qualitative* case that before/after misleads; this puts numbers on it.
# - Needs #21 and #22 recorded in `results/estimates.csv`.
# - **Neither** estimate handles the coincident media/promo activity from §3 — the honest recommendation probably carries a ceiling on attributable lift. Milestone #5 handles it properly.
#
# **Done when**
# - [ ] Both estimates side by side, gap quantified
# - [ ] Pros and cons stated plainly
# - [ ] A recommendation with its caveat
# - [ ] Comparison chart in `figures/simple_did/` at dpi=200
#
# Analysis helpers go in [`../../src/simple_did.py`](../../src/simple_did.py), not here — these
# notebooks get folded into `did_final.ipynb` later, same as `eda_tasks/` → `eda_final`.

# %%
import sys
sys.path.append("../../src")

import matplotlib.pyplot as plt
import pandas as pd

import simple_did as sd   # pre_post_split, rank_pre_period_fit, naive_estimate,
                          # manual_did, save_estimate -- see src/simple_did.py

df = sd.load_panel()
df.head()
